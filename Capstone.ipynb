# %% [markdown]
# # This Notebook is for Data Science Capstone Project

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course")
# Out:
# Hello Capstone Project Course

# %%
git clone  https://github.com/utkarshchoubeycs/Coursera_Capstone.git
# Out:
#   File "<ipython-input-2-a608c6343ecf>", line 1
#     git clone  https://github.com/utkarshchoubeycs/Coursera_Capstone.git
#             ^
# SyntaxError: invalid syntax
